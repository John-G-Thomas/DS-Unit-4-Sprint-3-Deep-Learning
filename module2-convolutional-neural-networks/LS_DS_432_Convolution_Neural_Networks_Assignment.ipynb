# %% [markdown]
# <a href="https://colab.research.google.com/github/John-G-Thomas/DS-Unit-4-Sprint-3-Deep-Learning/blob/main/module2-convolutional-neural-networks/LS_DS_432_Convolution_Neural_Networks_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# ## *Data Science Unit 4 Sprint 3 Assignment 2*
# # Convolutional Neural Networks (CNNs)

# %% [markdown]
# # Assignment
#
# - <a href="#p1">Part 1:</a> Pre-Trained Model
# - <a href="#p2">Part 2:</a> Custom CNN Model
# - <a href="#p3">Part 3:</a> CNN with Data Augmentation
#
#
# You will apply three different CNN models to a binary image classification model using Keras. Classify images of Mountains (`./data/train/mountain/*`) and images of forests (`./data/train/forest/*`). Treat mountains as the positive class (1) and the forest images as the negative (zero).
#
# |Mountain (+)|Forest (-)|
# |---|---|
# |![](https://github.com/LambdaSchool/DS-Unit-4-Sprint-3-Deep-Learning/blob/main/module2-convolutional-neural-networks/data/train/mountain/art1131.jpg?raw=1)|![](https://github.com/LambdaSchool/DS-Unit-4-Sprint-3-Deep-Learning/blob/main/module2-convolutional-neural-networks/data/validation/forest/cdmc317.jpg?raw=1)|
#
# The problem is relatively difficult given that the sample is tiny: there are about 350 observations per class. This sample size might be something that you can expect with prototyping an image classification problem/solution at work. Get accustomed to evaluating several different possible models.

# %% [markdown]
# # Pre - Trained Model
# <a id="p1"></a>
#
# Load a pretrained network from Keras, [ResNet50](https://tfhub.dev/google/imagenet/resnet_v1_50/classification/1) - a 50 layer deep network trained to recognize [1000 objects](https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt). Starting usage:
#
# ```python
# import numpy as np
#
# from tensorflow.keras.applications.resnet50 import ResNet50
# from tensorflow.keras.preprocessing import image
# from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
#
# from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
# from tensorflow.keras.models import Model # This is the functional API
#
# resnet = ResNet50(weights='imagenet', include_top=False)
#
# ```
#
# The `include_top` parameter in `ResNet50` will remove the full connected layers from the ResNet model. The next step is to turn off the training of the ResNet layers. We want to use the learned parameters without updating them in future training passes.
#
# ```python
# for layer in resnet.layers:
#     layer.trainable = False
# ```
#
# Using the Keras functional API, we will need to additional additional full connected layers to our model. We we removed the top layers, we removed all preivous fully connected layers. In other words, we kept only the feature processing portions of our network. You can expert with additional layers beyond what's listed here. The `GlobalAveragePooling2D` layer functions as a really fancy flatten function by taking the average of each of the last convolutional layer outputs (which is two dimensional still).
#
# ```python
# x = resnet.output
# x = GlobalAveragePooling2D()(x) # This layer is a really fancy flatten
# x = Dense(1024, activation='relu')(x)
# predictions = Dense(1, activation='sigmoid')(x)
# model = Model(resnet.input, predictions)
# ```
#
# Your assignment is to apply the transfer learning above to classify images of Mountains (`./data/train/mountain/*`) and images of forests (`./data/train/forest/*`). Treat mountains as the positive class (1) and the forest images as the negative (zero).
#
# Steps to complete assignment:
# 1. Load in Image Data into numpy arrays (`X`)
# 2. Create a `y` for the labels
# 3. Train your model with pre-trained layers from resnet
# 4. Report your model's accuracy

# %% [markdown]
# ## Load in Data
#
# This surprisingly more difficult than it seems, because you are working with directories of images instead of a single file. This boiler plate will help you download a zipped version of the directory of images. The directory is organized into "train" and "validation" which you can use inside an `ImageGenerator` class to stream batches of images thru your model.

# %% [markdown]
# ### Download & Summarize the Data
#
# This step is completed for you. Just run the cells and review the results.

# %%
import tensorflow as tf
import os

_URL = 'https://github.com/LambdaSchool/DS-Unit-4-Sprint-3-Deep-Learning/blob/main/module2-convolutional-neural-networks/data.zip?raw=true'

path_to_zip = tf.keras.utils.get_file('./data.zip', origin=_URL, extract=True)
PATH = os.path.join(os.path.dirname(path_to_zip), 'data')
# Out:
# Downloading data from https://github.com/LambdaSchool/DS-Unit-4-Sprint-3-Deep-Learning/blob/main/module2-convolutional-neural-networks/data.zip?raw=true
# 42172416/42170838 [==============================] - 0s 0us/step

# %%
train_dir = os.path.join(PATH, 'train')
validation_dir = os.path.join(PATH, 'validation')

# %%
train_mountain_dir = os.path.join(train_dir, 'mountain')  # directory with our training cat pictures
train_forest_dir = os.path.join(train_dir, 'forest')  # directory with our training dog pictures
validation_mountain_dir = os.path.join(validation_dir, 'mountain')  # directory with our validation cat pictures
validation_forest_dir = os.path.join(validation_dir, 'forest')  # directory with our validation dog pictures

# %%
num_mountain_tr = len(os.listdir(train_mountain_dir))
num_forest_tr = len(os.listdir(train_forest_dir))

num_mountain_val = len(os.listdir(validation_mountain_dir))
num_forest_val = len(os.listdir(validation_forest_dir))

total_train = num_mountain_tr + num_forest_tr
total_val = num_mountain_val + num_forest_val

# %%
print('total training mountain images:', num_mountain_tr)
print('total training forest images:', num_forest_tr)

print('total validation mountain images:', num_mountain_val)
print('total validation forest images:', num_forest_val)
print("--")
print("Total training images:", total_train)
print("Total validation images:", total_val)
# Out:
# total training mountain images: 254
# total training forest images: 270
# total validation mountain images: 125
# total validation forest images: 62
# --
# Total training images: 524
# Total validation images: 187

# %% [markdown]
# ### Keras `ImageGenerator` to Process the Data
#
# This step is completed for you, but please review the code. The `ImageGenerator` class reads in batches of data from a directory and pass them to the model one batch at a time. Just like large text files, this method is advantageous, because it stifles the need to load a bunch of images into memory.
#
# Check out the documentation for this class method: [Keras `ImageGenerator` Class](https://keras.io/preprocessing/image/#imagedatagenerator-class). You'll expand it's use in the third assignment objective.

# %%
batch_size = 16
epochs = 50
IMG_HEIGHT = 224
IMG_WIDTH = 224

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_image_generator = ImageDataGenerator(rescale=1./255) # Generator for our training data
validation_image_generator = ImageDataGenerator(rescale=1./255) # Generator for our validation data

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=batch_size,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_HEIGHT, IMG_WIDTH),
                                                           class_mode='binary')
# Out:
# Found 533 images belonging to 2 classes.

# %%
val_data_gen = validation_image_generator.flow_from_directory(batch_size=batch_size,
                                                              directory=validation_dir,
                                                              target_size=(IMG_HEIGHT, IMG_WIDTH),
                                                              class_mode='binary')
# Out:
# Found 195 images belonging to 2 classes.

# %% [markdown]
# ## Instatiate Model

# %%
import numpy as np
# for images - model - layers
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout

# %%
resnet = ResNet50(weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step

# %%
for layer in resnet.layers:
    layer.trainable = False

x = resnet.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x)
model = Model(resnet.input, predictions)

model.compile(optimizer='Nadam', loss='binary_crossentropy', metrics=['binary_accuracy'])

# %% [markdown]
# ## Fit Model

# %%
history = model.fit(
    train_data_gen,
    steps_per_epoch=total_train // batch_size,
    epochs=epochs,
    validation_data=val_data_gen,
    validation_steps=total_val // batch_size
)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 3s 107ms/step - loss: 0.8509 - binary_accuracy: 0.5030 - val_loss: 1.0171 - val_binary_accuracy: 0.3466
# Epoch 2/50
# 32/32 [==============================] - 2s 77ms/step - loss: 0.6348 - binary_accuracy: 0.6547 - val_loss: 0.6600 - val_binary_accuracy: 0.5511
# Epoch 3/50
# 32/32 [==============================] - 2s 77ms/step - loss: 0.6198 - binary_accuracy: 0.6826 - val_loss: 0.6425 - val_binary_accuracy: 0.6023
# Epoch 4/50
# 32/32 [==============================] - 2s 77ms/step - loss: 0.5440 - binary_accuracy: 0.7026 - val_loss: 0.6448 - val_binary_accuracy: 0.6250
# Epoch 5/50
# 32/32 [==============================] - 2s 78ms/step - loss: 0.5481 - binary_accuracy: 0.7046 - val_loss: 1.8341 - val_binary_accuracy: 0.3409
# Epoch 6/50
# 32/32 [==============================] - 2s 78ms/step - loss: 0.5063 - binary_accuracy: 0.7585 - val_loss: 0.7566 - val_binary_accuracy: 0.4830
# Epoch 7/50
# 32/32 [==============================] - 2s 78ms/step - loss: 0.4821 - binary_accuracy: 0.7844 - val_loss: 0.4264 - val_binary_accuracy: 0.8523
# Epoch 8/50
# 32/32 [==============================] - 3s 79ms/step - loss: 0.3931 - binary_accuracy: 0.8643 - val_loss: 0.3595 - val_binary_accuracy: 0.8239
# Epoch 9/50
# 32/32 [==============================] - 2s 78ms/step - loss: 0.4407 - binary_accuracy: 0.7904 - val_loss: 0.3623 - val_binary_accuracy: 0.8182
# Epoch 10/50
# 32/32 [==============================] - 3s 79ms/step - loss: 0.3939 - binary_accuracy: 0.8323 - val_loss: 0.3626 - val_binary_accuracy: 0.8807
# Epoch 11/50
# 32/32 [==============================] - 2s 78ms/step - loss: 0.3806 - binary_accuracy: 0.8483 - val_loss: 0.3595 - val_binary_accuracy: 0.8068
# Epoch 12/50
# 32/32 [==============================] - 3s 79ms/step - loss: 0.3288 - binary_accuracy: 0.8663 - val_loss: 0.4047 - val_binary_accuracy: 0.7614
# Epoch 13/50
# 32/32 [==============================] - 2s 78ms/step - loss: 0.3662 - binary_accuracy: 0.8483 - val_loss: 0.3952 - val_binary_accuracy: 0.8523
# Epoch 14/50
# 32/32 [==============================] - 3s 79ms/step - loss: 0.4070 - binary_accuracy: 0.8303 - val_loss: 0.4003 - val_binary_accuracy: 0.7557
# Epoch 15/50
# 32/32 [==============================] - 3s 78ms/step - loss: 0.3433 - binary_accuracy: 0.8503 - val_loss: 0.3011 - val_binary_accuracy: 0.9091
# Epoch 16/50
# 32/32 [==============================] - 3s 80ms/step - loss: 0.2964 - binary_accuracy: 0.8965 - val_loss: 0.5553 - val_binary_accuracy: 0.7500
# Epoch 17/50
# 32/32 [==============================] - 3s 79ms/step - loss: 0.2854 - binary_accuracy: 0.8842 - val_loss: 0.3128 - val_binary_accuracy: 0.8920
# Epoch 18/50
# 32/32 [==============================] - 3s 79ms/step - loss: 0.3763 - binary_accuracy: 0.8443 - val_loss: 0.3767 - val_binary_accuracy: 0.7784
# Epoch 19/50
# 32/32 [==============================] - 3s 79ms/step - loss: 0.2936 - binary_accuracy: 0.8922 - val_loss: 0.2933 - val_binary_accuracy: 0.9034
# Epoch 20/50
# 32/32 [==============================] - 3s 79ms/step - loss: 0.3604 - binary_accuracy: 0.8703 - val_loss: 0.3233 - val_binary_accuracy: 0.8693
# Epoch 21/50
# 32/32 [==============================] - 3s 79ms/step - loss: 0.2812 - binary_accuracy: 0.8942 - val_loss: 0.2495 - val_binary_accuracy: 0.9091
# Epoch 22/50
# 32/32 [==============================] - 3s 80ms/step - loss: 0.2392 - binary_accuracy: 0.9102 - val_loss: 0.3442 - val_binary_accuracy: 0.8182
# Epoch 23/50
# 32/32 [==============================] - 3s 80ms/step - loss: 0.2476 - binary_accuracy: 0.9102 - val_loss: 0.2659 - val_binary_accuracy: 0.9091
# Epoch 24/50
# 32/32 [==============================] - 3s 80ms/step - loss: 0.3700 - binary_accuracy: 0.8583 - val_loss: 0.2629 - val_binary_accuracy: 0.9034
# Epoch 25/50
# 32/32 [==============================] - 3s 79ms/step - loss: 0.2231 - binary_accuracy: 0.9202 - val_loss: 0.2550 - val_binary_accuracy: 0.9148
# Epoch 26/50
# 32/32 [==============================] - 3s 80ms/step - loss: 0.2141 - binary_accuracy: 0.9202 - val_loss: 0.2522 - val_binary_accuracy: 0.9205
# Epoch 27/50
# 32/32 [==============================] - 3s 79ms/step - loss: 0.2505 - binary_accuracy: 0.9162 - val_loss: 0.2614 - val_binary_accuracy: 0.8977
# Epoch 28/50
# 32/32 [==============================] - 3s 80ms/step - loss: 0.1896 - binary_accuracy: 0.9461 - val_loss: 0.2182 - val_binary_accuracy: 0.9091
# Epoch 29/50
# 32/32 [==============================] - 3s 80ms/step - loss: 0.3224 - binary_accuracy: 0.8762 - val_loss: 0.6509 - val_binary_accuracy: 0.6875
# Epoch 30/50
# 32/32 [==============================] - 3s 80ms/step - loss: 0.2896 - binary_accuracy: 0.8822 - val_loss: 0.2632 - val_binary_accuracy: 0.8807
# Epoch 31/50
# 32/32 [==============================] - 3s 80ms/step - loss: 0.2071 - binary_accuracy: 0.9222 - val_loss: 0.3084 - val_binary_accuracy: 0.8750
# Epoch 32/50
# 32/32 [==============================] - 3s 80ms/step - loss: 0.2073 - binary_accuracy: 0.9321 - val_loss: 0.2297 - val_binary_accuracy: 0.9375
# Epoch 33/50
# 32/32 [==============================] - 3s 81ms/step - loss: 0.1933 - binary_accuracy: 0.9321 - val_loss: 0.2852 - val_binary_accuracy: 0.8750
# Epoch 34/50
# 32/32 [==============================] - 3s 80ms/step - loss: 0.1916 - binary_accuracy: 0.9258 - val_loss: 0.2324 - val_binary_accuracy: 0.9318
# Epoch 35/50
# 32/32 [==============================] - 3s 80ms/step - loss: 0.2398 - binary_accuracy: 0.9022 - val_loss: 0.2293 - val_binary_accuracy: 0.9375
# Epoch 36/50
# 32/32 [==============================] - 3s 81ms/step - loss: 0.2100 - binary_accuracy: 0.9222 - val_loss: 0.2451 - val_binary_accuracy: 0.8920
# Epoch 37/50
# 32/32 [==============================] - 3s 81ms/step - loss: 0.1663 - binary_accuracy: 0.9321 - val_loss: 0.2204 - val_binary_accuracy: 0.9375
# Epoch 38/50
# 32/32 [==============================] - 3s 81ms/step - loss: 0.1367 - binary_accuracy: 0.9561 - val_loss: 0.2220 - val_binary_accuracy: 0.9205
# Epoch 39/50
# 32/32 [==============================] - 3s 82ms/step - loss: 0.1319 - binary_accuracy: 0.9551 - val_loss: 0.2625 - val_binary_accuracy: 0.8920
# Epoch 40/50
# 32/32 [==============================] - 3s 81ms/step - loss: 0.1827 - binary_accuracy: 0.9361 - val_loss: 0.2102 - val_binary_accuracy: 0.9375
# Epoch 41/50
# 32/32 [==============================] - 3s 80ms/step - loss: 0.1315 - binary_accuracy: 0.9541 - val_loss: 0.5043 - val_binary_accuracy: 0.8125
# Epoch 42/50
# 32/32 [==============================] - 3s 81ms/step - loss: 0.1616 - binary_accuracy: 0.9242 - val_loss: 0.2017 - val_binary_accuracy: 0.9489
# Epoch 43/50
# 32/32 [==============================] - 3s 80ms/step - loss: 0.1444 - binary_accuracy: 0.9421 - val_loss: 0.2111 - val_binary_accuracy: 0.9432
# Epoch 44/50
# 32/32 [==============================] - 3s 80ms/step - loss: 0.1574 - binary_accuracy: 0.9341 - val_loss: 0.2639 - val_binary_accuracy: 0.8977
# Epoch 45/50
# 32/32 [==============================] - 3s 81ms/step - loss: 0.1996 - binary_accuracy: 0.9297 - val_loss: 0.2594 - val_binary_accuracy: 0.8977
# Epoch 46/50
# 32/32 [==============================] - 3s 81ms/step - loss: 0.1057 - binary_accuracy: 0.9629 - val_loss: 0.1964 - val_binary_accuracy: 0.9432
# Epoch 47/50
# 32/32 [==============================] - 3s 82ms/step - loss: 0.2742 - binary_accuracy: 0.9102 - val_loss: 0.2097 - val_binary_accuracy: 0.9375
# Epoch 48/50
# 32/32 [==============================] - 3s 80ms/step - loss: 0.1175 - binary_accuracy: 0.9629 - val_loss: 0.1865 - val_binary_accuracy: 0.9489
# Epoch 49/50
# 32/32 [==============================] - 3s 80ms/step - loss: 0.1219 - binary_accuracy: 0.9561 - val_loss: 0.7373 - val_binary_accuracy: 0.7273
# Epoch 50/50
# 32/32 [==============================] - 3s 80ms/step - loss: 0.1780 - binary_accuracy: 0.9321 - val_loss: 0.2199 - val_binary_accuracy: 0.9318

# %%
import matplotlib.pyplot as plt
# Vizalizet the relationship between train and val accuracy
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# # Custom CNN Model
#
# In this step, write and train your own convolutional neural network using Keras. You can use any architecture that suits you as long as it has at least one convolutional and one pooling layer at the beginning of the network - you can add more if you want.

# %%
# Define the Model 224, 224, 3
# Setup Architecture
model = Sequential()
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 64)        36928
# _________________________________________________________________
# flatten (Flatten)            (None, 173056)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                11075648
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                650
# =================================================================
# Total params: 11,132,618
# Trainable params: 11,132,618
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile Model
model.compile(optimizer='Nadam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Fit Model
custom = model.fit(
    train_data_gen,
    epochs=50,
    validation_data=val_data_gen
)
# Out:
# Epoch 1/50
# 34/34 [==============================] - 2s 67ms/step - loss: 0.6936 - accuracy: 0.7167 - val_loss: 0.2297 - val_accuracy: 0.9179
# Epoch 2/50
# 34/34 [==============================] - 2s 61ms/step - loss: 0.2669 - accuracy: 0.8837 - val_loss: 0.2141 - val_accuracy: 0.9179
# Epoch 3/50
# 34/34 [==============================] - 2s 61ms/step - loss: 0.2425 - accuracy: 0.9193 - val_loss: 0.3386 - val_accuracy: 0.8410
# Epoch 4/50
# 34/34 [==============================] - 2s 61ms/step - loss: 0.2442 - accuracy: 0.9099 - val_loss: 0.2864 - val_accuracy: 0.8462
# Epoch 5/50
# 34/34 [==============================] - 2s 60ms/step - loss: 0.2130 - accuracy: 0.9174 - val_loss: 0.1977 - val_accuracy: 0.9179
# Epoch 6/50
# 34/34 [==============================] - 2s 63ms/step - loss: 0.1560 - accuracy: 0.9456 - val_loss: 0.1789 - val_accuracy: 0.9385
# Epoch 7/50
# 34/34 [==============================] - 2s 62ms/step - loss: 0.1402 - accuracy: 0.9512 - val_loss: 0.2682 - val_accuracy: 0.8974
# Epoch 8/50
# 34/34 [==============================] - 2s 62ms/step - loss: 0.1848 - accuracy: 0.9606 - val_loss: 0.2178 - val_accuracy: 0.9179
# Epoch 9/50
# 34/34 [==============================] - 2s 62ms/step - loss: 0.1242 - accuracy: 0.9550 - val_loss: 0.2792 - val_accuracy: 0.8872
# Epoch 10/50
# 34/34 [==============================] - 2s 61ms/step - loss: 0.1993 - accuracy: 0.9174 - val_loss: 0.2089 - val_accuracy: 0.8923
# Epoch 11/50
# 34/34 [==============================] - 2s 61ms/step - loss: 0.1353 - accuracy: 0.9437 - val_loss: 0.5789 - val_accuracy: 0.7487
# Epoch 12/50
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0984 - accuracy: 0.9550 - val_loss: 0.1746 - val_accuracy: 0.9333
# Epoch 13/50
# 34/34 [==============================] - 2s 60ms/step - loss: 0.1164 - accuracy: 0.9606 - val_loss: 0.2373 - val_accuracy: 0.9179
# Epoch 14/50
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0556 - accuracy: 0.9794 - val_loss: 0.8378 - val_accuracy: 0.7846
# Epoch 15/50
# 34/34 [==============================] - 2s 60ms/step - loss: 0.1062 - accuracy: 0.9512 - val_loss: 0.3916 - val_accuracy: 0.8462
# Epoch 16/50
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0444 - accuracy: 0.9887 - val_loss: 0.2742 - val_accuracy: 0.9179
# Epoch 17/50
# 34/34 [==============================] - 2s 62ms/step - loss: 0.0314 - accuracy: 0.9887 - val_loss: 0.3585 - val_accuracy: 0.8872
# Epoch 18/50
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.3109 - val_accuracy: 0.9231
# Epoch 19/50
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.2835 - val_accuracy: 0.9333
# Epoch 20/50
# 34/34 [==============================] - 2s 62ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.3137 - val_accuracy: 0.9282
# Epoch 21/50
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.3164 - val_accuracy: 0.9385
# Epoch 22/50
# 34/34 [==============================] - 2s 62ms/step - loss: 0.0133 - accuracy: 0.9962 - val_loss: 0.3753 - val_accuracy: 0.9231
# Epoch 23/50
# 34/34 [==============================] - 2s 62ms/step - loss: 0.0074 - accuracy: 0.9981 - val_loss: 0.3032 - val_accuracy: 0.9385
# Epoch 24/50
# 34/34 [==============================] - 2s 61ms/step - loss: 0.5216 - accuracy: 0.8780 - val_loss: 0.2377 - val_accuracy: 0.8923
# Epoch 25/50
# 34/34 [==============================] - 2s 62ms/step - loss: 0.2075 - accuracy: 0.9362 - val_loss: 0.1743 - val_accuracy: 0.9282
# Epoch 26/50
# 34/34 [==============================] - 2s 62ms/step - loss: 0.0721 - accuracy: 0.9719 - val_loss: 0.2449 - val_accuracy: 0.9179
# Epoch 27/50
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0765 - accuracy: 0.9719 - val_loss: 0.1411 - val_accuracy: 0.9333
# Epoch 28/50
# 34/34 [==============================] - 2s 62ms/step - loss: 0.0490 - accuracy: 0.9850 - val_loss: 0.1797 - val_accuracy: 0.9333
# Epoch 29/50
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0214 - accuracy: 0.9944 - val_loss: 0.2810 - val_accuracy: 0.9077
# Epoch 30/50
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0242 - accuracy: 0.9906 - val_loss: 0.2013 - val_accuracy: 0.9282
# Epoch 31/50
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0072 - accuracy: 0.9981 - val_loss: 0.2644 - val_accuracy: 0.9385
# Epoch 32/50
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0449 - accuracy: 0.9850 - val_loss: 0.1771 - val_accuracy: 0.9179
# Epoch 33/50
# 34/34 [==============================] - 2s 61ms/step - loss: 0.1484 - accuracy: 0.9531 - val_loss: 0.2551 - val_accuracy: 0.9026
# Epoch 34/50
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0423 - accuracy: 0.9869 - val_loss: 0.2548 - val_accuracy: 0.9077
# Epoch 35/50
# 34/34 [==============================] - 2s 62ms/step - loss: 0.0372 - accuracy: 0.9887 - val_loss: 0.3279 - val_accuracy: 0.9026
# Epoch 36/50
# 34/34 [==============================] - 2s 62ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.2675 - val_accuracy: 0.9231
# Epoch 37/50
# 34/34 [==============================] - 2s 62ms/step - loss: 0.0065 - accuracy: 0.9962 - val_loss: 0.4059 - val_accuracy: 0.9026
# Epoch 38/50
# 34/34 [==============================] - 2s 63ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2563 - val_accuracy: 0.9385
# Epoch 39/50
# 34/34 [==============================] - 2s 63ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.3079 - val_accuracy: 0.9385
# Epoch 40/50
# 34/34 [==============================] - 2s 61ms/step - loss: 7.2458e-04 - accuracy: 1.0000 - val_loss: 0.3240 - val_accuracy: 0.9385
# Epoch 41/50
# 34/34 [==============================] - 2s 61ms/step - loss: 9.1272e-04 - accuracy: 1.0000 - val_loss: 0.4526 - val_accuracy: 0.9077
# Epoch 42/50
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0054 - accuracy: 0.9962 - val_loss: 0.2958 - val_accuracy: 0.9385
# Epoch 43/50
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3496 - val_accuracy: 0.9282
# Epoch 44/50
# 34/34 [==============================] - 2s 62ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3155 - val_accuracy: 0.9436
# Epoch 45/50
# 34/34 [==============================] - 2s 62ms/step - loss: 0.0053 - accuracy: 0.9981 - val_loss: 0.3015 - val_accuracy: 0.9436
# Epoch 46/50
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.3185 - val_accuracy: 0.9436
# Epoch 47/50
# 34/34 [==============================] - 2s 59ms/step - loss: 0.0061 - accuracy: 0.9962 - val_loss: 0.2924 - val_accuracy: 0.9385
# Epoch 48/50
# 34/34 [==============================] - 2s 58ms/step - loss: 7.8764e-04 - accuracy: 1.0000 - val_loss: 0.4276 - val_accuracy: 0.9179
# Epoch 49/50
# 34/34 [==============================] - 2s 59ms/step - loss: 4.6654e-04 - accuracy: 1.0000 - val_loss: 0.3644 - val_accuracy: 0.9333
# Epoch 50/50
# 34/34 [==============================] - 2s 58ms/step - loss: 4.2202e-04 - accuracy: 1.0000 - val_loss: 0.3716 - val_accuracy: 0.9385

# %%
# Evaluate Model 

model.evaluate(val_data_gen)
# Out:
# 13/13 [==============================] - 0s 30ms/step - loss: 0.3716 - accuracy: 0.9385
# [0.3715522587299347, 0.9384615421295166]

# %%
# Vizalizet the relationship between train and val accuracy
accc = custom.history['accuracy']
val_accc = custom.history['val_accuracy']

losss = custom.history['loss']
val_losss = custom.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(accc, label='Training Accuracy')
plt.plot(val_accc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(losss, label='Training Loss')
plt.plot(val_losss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# # Custom CNN Model with Image Manipulations
#
# To simulate an increase in a sample of image, you can apply image manipulation techniques: cropping, rotation, stretching, etc. Luckily Keras has some handy functions for us to apply these techniques to our mountain and forest example. Simply, you should be able to modify our image generator for the problem. Check out these resources to help you get started:
#
# 1. [Keras `ImageGenerator` Class](https://keras.io/preprocessing/image/#imagedatagenerator-class)
# 2. [Building a powerful image classifier with very little data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html)

# %%
train_image_generator = ImageDataGenerator(rescale=1./255, rotation_range=90, width_shift_range=.5, height_shift_range=.5)
validation_image_generator = ImageDataGenerator(rescale=1./255, rotation_range=90, width_shift_range=.5, height_shift_range=.5)

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=batch_size,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_HEIGHT, IMG_WIDTH),
                                                           class_mode='binary')
# Out:
# Found 533 images belonging to 2 classes.

# %%
val_data_gen = validation_image_generator.flow_from_directory(batch_size=batch_size,
                                                              directory=validation_dir,
                                                              target_size=(IMG_HEIGHT, IMG_WIDTH),
                                                              class_mode='binary')
# Out:
# Found 195 images belonging to 2 classes.

# %%
# Define the Model 224, 224, 3
# Setup Architecture
model = Sequential()
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 111, 111, 32)      0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 52, 52, 64)        36928
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 173056)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                11075648
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                650
# =================================================================
# Total params: 11,132,618
# Trainable params: 11,132,618
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile Model
model.compile(optimizer='Nadam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
imagemal = model.fit(
    train_data_gen,
    epochs=30,batch_size=2,
    validation_data=val_data_gen
)
# Out:
# Epoch 1/30
# 34/34 [==============================] - 9s 264ms/step - loss: 1.2487 - accuracy: 0.5985 - val_loss: 0.3732 - val_accuracy: 0.8615
# Epoch 2/30
# 34/34 [==============================] - 9s 253ms/step - loss: 0.4866 - accuracy: 0.8124 - val_loss: 0.4707 - val_accuracy: 0.8513
# Epoch 3/30
# 34/34 [==============================] - 9s 254ms/step - loss: 0.3711 - accuracy: 0.8405 - val_loss: 0.3669 - val_accuracy: 0.8410
# Epoch 4/30
# 34/34 [==============================] - 9s 260ms/step - loss: 0.3966 - accuracy: 0.8574 - val_loss: 0.4052 - val_accuracy: 0.8205
# Epoch 5/30
# 34/34 [==============================] - 9s 256ms/step - loss: 0.3640 - accuracy: 0.8649 - val_loss: 0.4665 - val_accuracy: 0.8308
# Epoch 6/30
# 34/34 [==============================] - 9s 259ms/step - loss: 0.3260 - accuracy: 0.8837 - val_loss: 0.2690 - val_accuracy: 0.8821
# Epoch 7/30
# 34/34 [==============================] - 9s 254ms/step - loss: 0.3548 - accuracy: 0.8555 - val_loss: 0.3745 - val_accuracy: 0.8154
# Epoch 8/30
# 34/34 [==============================] - 9s 254ms/step - loss: 0.2692 - accuracy: 0.8912 - val_loss: 0.2277 - val_accuracy: 0.8872
# Epoch 9/30
# 34/34 [==============================] - 9s 254ms/step - loss: 0.3502 - accuracy: 0.8705 - val_loss: 0.3198 - val_accuracy: 0.8872
# Epoch 10/30
# 34/34 [==============================] - 9s 254ms/step - loss: 0.3052 - accuracy: 0.8856 - val_loss: 0.4669 - val_accuracy: 0.8256
# Epoch 11/30
# 34/34 [==============================] - 9s 254ms/step - loss: 0.2674 - accuracy: 0.9024 - val_loss: 0.2498 - val_accuracy: 0.8872
# Epoch 12/30
# 34/34 [==============================] - 9s 253ms/step - loss: 0.2731 - accuracy: 0.8931 - val_loss: 0.3145 - val_accuracy: 0.8769
# Epoch 13/30
# 34/34 [==============================] - 9s 255ms/step - loss: 0.3271 - accuracy: 0.8668 - val_loss: 0.3275 - val_accuracy: 0.8615
# Epoch 14/30
# 34/34 [==============================] - 9s 255ms/step - loss: 0.2661 - accuracy: 0.8949 - val_loss: 0.3283 - val_accuracy: 0.8359
# Epoch 15/30
# 34/34 [==============================] - 9s 253ms/step - loss: 0.2867 - accuracy: 0.8856 - val_loss: 0.4550 - val_accuracy: 0.7949
# Epoch 16/30
# 34/34 [==============================] - 9s 251ms/step - loss: 0.2933 - accuracy: 0.8912 - val_loss: 0.4333 - val_accuracy: 0.8154
# Epoch 17/30
# 34/34 [==============================] - 9s 257ms/step - loss: 0.2664 - accuracy: 0.8931 - val_loss: 0.3250 - val_accuracy: 0.8615
# Epoch 18/30
# 34/34 [==============================] - 9s 255ms/step - loss: 0.2710 - accuracy: 0.9043 - val_loss: 0.2753 - val_accuracy: 0.8513
# Epoch 19/30
# 34/34 [==============================] - 9s 255ms/step - loss: 0.2485 - accuracy: 0.8987 - val_loss: 0.3663 - val_accuracy: 0.8308
# Epoch 20/30
# 34/34 [==============================] - 9s 255ms/step - loss: 0.3127 - accuracy: 0.8743 - val_loss: 0.3289 - val_accuracy: 0.8667
# Epoch 21/30
# 34/34 [==============================] - 9s 256ms/step - loss: 0.2972 - accuracy: 0.8949 - val_loss: 0.3066 - val_accuracy: 0.8308
# Epoch 22/30
# 34/34 [==============================] - 9s 253ms/step - loss: 0.2900 - accuracy: 0.9006 - val_loss: 0.3437 - val_accuracy: 0.8462
# Epoch 23/30
# 34/34 [==============================] - 9s 253ms/step - loss: 0.2493 - accuracy: 0.9081 - val_loss: 0.2706 - val_accuracy: 0.8821
# Epoch 24/30
# 34/34 [==============================] - 9s 253ms/step - loss: 0.2401 - accuracy: 0.9137 - val_loss: 0.2472 - val_accuracy: 0.8974
# Epoch 25/30
# 34/34 [==============================] - 9s 255ms/step - loss: 0.2627 - accuracy: 0.9118 - val_loss: 0.2704 - val_accuracy: 0.9179
# Epoch 26/30
# 34/34 [==============================] - 9s 257ms/step - loss: 0.3828 - accuracy: 0.8462 - val_loss: 0.2596 - val_accuracy: 0.9026
# Epoch 27/30
# 34/34 [==============================] - 9s 255ms/step - loss: 0.3780 - accuracy: 0.8705 - val_loss: 0.2532 - val_accuracy: 0.8667
# Epoch 28/30
# 34/34 [==============================] - 9s 254ms/step - loss: 0.2571 - accuracy: 0.9137 - val_loss: 0.2785 - val_accuracy: 0.8821
# Epoch 29/30
# 34/34 [==============================] - 9s 253ms/step - loss: 0.2597 - accuracy: 0.9006 - val_loss: 0.2783 - val_accuracy: 0.8821
# Epoch 30/30
# 34/34 [==============================] - 9s 255ms/step - loss: 0.2258 - accuracy: 0.9118 - val_loss: 0.3478 - val_accuracy: 0.8462

# %%
# Evaluate Model

model.evaluate(val_data_gen)
# Out:
# 13/13 [==============================] - 2s 158ms/step - loss: 0.2750 - accuracy: 0.8769
# [0.27496644854545593, 0.8769230842590332]

# %%
# Evaluate Model

model.evaluate(train_data_gen)
# Out:
# 34/34 [==============================] - 6s 179ms/step - loss: 0.2322 - accuracy: 0.8949
# [0.23223325610160828, 0.894934356212616]

# %%
# Vizalizet the relationship between train and val accuracy
acc = imagemal.history['accuracy']
val_acc = imagemal.history['val_accuracy']

loss = imagemal.history['loss']
val_loss = imagemal.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
import numpy as np

from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions

def process_img_path(img_path):
  return image.load_img(img_path, target_size=(224, 224))

def img_contains_banana(img):
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
  x = preprocess_input(x)
  model = ResNet50(weights='imagenet')
  features = model.predict(x)
  results = decode_predictions(features, top=3)[0]
  print(results)
  for entry in results:
    if entry[1] == 'banana':
      return entry[2]
  return 0.0

# %%
import requests

image_urls = ["https://github.com/LambdaSchool/DS-Unit-4-Sprint-3-Deep-Learning/blob/main/module2-convolutional-neural-networks/data/train/mountain/art1131.jpg?raw=1",
              "https://github.com/LambdaSchool/DS-Unit-4-Sprint-3-Deep-Learning/blob/main/module2-convolutional-neural-networks/data/validation/forest/cdmc317.jpg?raw=1",
              "https://github.com/LambdaSchool/ML-YouOnlyLookOnce/raw/master/sample_data/positive_examples/example0.jpeg",
              "https://github.com/LambdaSchool/ML-YouOnlyLookOnce/raw/master/sample_data/positive_examples/example1.jpeg",
              "https://github.com/LambdaSchool/ML-YouOnlyLookOnce/raw/master/sample_data/positive_examples/example2.jpeg"]

for _id,img in enumerate(image_urls): 
    r = requests.get(img)
    with open(f'example{_id}.jpg', 'wb') as f:
        f.write(r.content)

# %%
from IPython.display import Image
Image(filename='./example0.jpg', width=600)

# %%
img_contains_banana(process_img_path('example0.jpg'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102973440/102967424 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 40960/35363 [==================================] - 0s 0us/step
# [('n03532672', 'hook', 0.077739626), ('n07753592', 'banana', 0.07015056), ('n03498962', 'hatchet', 0.06332093)]
# 0.07015056

# %%
Image(filename='example1.jpg', width=600)

# %%
img_contains_banana(process_img_path('example1.jpg'))
# Out:
# [('n04275548', 'spider_web', 0.27565345), ('n02909870', 'bucket', 0.085777074), ('n03532672', 'hook', 0.07912184)]
# 0.0

# %%
Image(filename='example1.jpg', width=600)

# %%
img_contains_banana(process_img_path('example1.jpg'))
# Out:
# [('n04275548', 'spider_web', 0.27565345), ('n02909870', 'bucket', 0.085777074), ('n03532672', 'hook', 0.07912184)]
# 0.0

# %%
Image(filename='example2.jpg', width=600)

# %%
img_contains_banana(process_img_path('example2.jpg'))
# Out:
# [('n07753592', 'banana', 0.9903453), ('n07747607', 'orange', 0.0051709744), ('n07749582', 'lemon', 0.003187234)]
# 0.9903453

# %%
Image(filename='art1131.jpg', width=600)

# %%
img_contains_banana(process_img_path('art1131.jpg'))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe23cc6df28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [('n09193705', 'alp', 0.9799672), ('n09468604', 'valley', 0.0051116846), ('n04228054', 'ski', 0.0019172073)]
# 0.0

# %%
Image(filename='cdmc317.jpg', width=600)

# %%
img_contains_banana(process_img_path('cdmc317.jpg'))
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe23ba98510> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [('n09332890', 'lakeside', 0.3146781), ('n09193705', 'alp', 0.097549684), ('n04589890', 'window_screen', 0.0675493)]
# 0.0

# %% [markdown]
# # Resources and Stretch Goals
#
# Stretch goals
# - Enhance your code to use classes/functions and accept terms to search and classes to look for in recognizing the downloaded images (e.g. download images of parties, recognize all that contain balloons)
# - Check out [other available pretrained networks](https://tfhub.dev), try some and compare
# - Image recognition/classification is somewhat solved, but *relationships* between entities and describing an image is not - check out some of the extended resources (e.g. [Visual Genome](https://visualgenome.org/)) on the topic
# - Transfer learning - using images you source yourself, [retrain a classifier](https://www.tensorflow.org/hub/tutorials/image_retraining) with a new category
# - (Not CNN related) Use [piexif](https://pypi.org/project/piexif/) to check out the metadata of images passed in to your system - see if they're from a national park! (Note - many images lack GPS metadata, so this won't work in most cases, but still cool)
#
# Resources
# - [Deep Residual Learning for Image Recognition](https://arxiv.org/abs/1512.03385) - influential paper (introduced ResNet)
# - [YOLO: Real-Time Object Detection](https://pjreddie.com/darknet/yolo/) - an influential convolution based object detection system, focused on inference speed (for applications to e.g. self driving vehicles)
# - [R-CNN, Fast R-CNN, Faster R-CNN, YOLO](https://towardsdatascience.com/r-cnn-fast-r-cnn-faster-r-cnn-yolo-object-detection-algorithms-36d53571365e) - comparison of object detection systems
# - [Common Objects in Context](http://cocodataset.org/) - a large-scale object detection, segmentation, and captioning dataset
# - [Visual Genome](https://visualgenome.org/) - a dataset, a knowledge base, an ongoing effort to connect structured image concepts to language
