# %% [markdown]
# <a href="https://colab.research.google.com/github/John-G-Thomas/DS-Unit-4-Sprint-3-Deep-Learning/blob/main/module2-convolutional-neural-networks/LS_DS_432_Convolution_Neural_Networks_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# ## *Data Science Unit 4 Sprint 3 Assignment 2*
# # Convolutional Neural Networks (CNNs)

# %% [markdown]
# # Assignment
#
# - <a href="#p1">Part 1:</a> Pre-Trained Model
# - <a href="#p2">Part 2:</a> Custom CNN Model
# - <a href="#p3">Part 3:</a> CNN with Data Augmentation
#
#
# You will apply three different CNN models to a binary image classification model using Keras. Classify images of Mountains (`./data/train/mountain/*`) and images of forests (`./data/train/forest/*`). Treat mountains as the positive class (1) and the forest images as the negative (zero).
#
# |Mountain (+)|Forest (-)|
# |---|---|
# |![](https://github.com/LambdaSchool/DS-Unit-4-Sprint-3-Deep-Learning/blob/main/module2-convolutional-neural-networks/data/train/mountain/art1131.jpg?raw=1)|![](https://github.com/LambdaSchool/DS-Unit-4-Sprint-3-Deep-Learning/blob/main/module2-convolutional-neural-networks/data/validation/forest/cdmc317.jpg?raw=1)|
#
# The problem is relatively difficult given that the sample is tiny: there are about 350 observations per class. This sample size might be something that you can expect with prototyping an image classification problem/solution at work. Get accustomed to evaluating several different possible models.

# %% [markdown]
# # Pre - Trained Model
# <a id="p1"></a>
#
# Load a pretrained network from Keras, [ResNet50](https://tfhub.dev/google/imagenet/resnet_v1_50/classification/1) - a 50 layer deep network trained to recognize [1000 objects](https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt). Starting usage:
#
# ```python
# import numpy as np
#
# from tensorflow.keras.applications.resnet50 import ResNet50
# from tensorflow.keras.preprocessing import image
# from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
#
# from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
# from tensorflow.keras.models import Model # This is the functional API
#
# resnet = ResNet50(weights='imagenet', include_top=False)
#
# ```
#
# The `include_top` parameter in `ResNet50` will remove the full connected layers from the ResNet model. The next step is to turn off the training of the ResNet layers. We want to use the learned parameters without updating them in future training passes.
#
# ```python
# for layer in resnet.layers:
#     layer.trainable = False
# ```
#
# Using the Keras functional API, we will need to additional additional full connected layers to our model. We we removed the top layers, we removed all preivous fully connected layers. In other words, we kept only the feature processing portions of our network. You can expert with additional layers beyond what's listed here. The `GlobalAveragePooling2D` layer functions as a really fancy flatten function by taking the average of each of the last convolutional layer outputs (which is two dimensional still).
#
# ```python
# x = resnet.output
# x = GlobalAveragePooling2D()(x) # This layer is a really fancy flatten
# x = Dense(1024, activation='relu')(x)
# predictions = Dense(1, activation='sigmoid')(x)
# model = Model(resnet.input, predictions)
# ```
#
# Your assignment is to apply the transfer learning above to classify images of Mountains (`./data/train/mountain/*`) and images of forests (`./data/train/forest/*`). Treat mountains as the positive class (1) and the forest images as the negative (zero).
#
# Steps to complete assignment:
# 1. Load in Image Data into numpy arrays (`X`)
# 2. Create a `y` for the labels
# 3. Train your model with pre-trained layers from resnet
# 4. Report your model's accuracy

# %% [markdown]
# ## Load in Data
#
# This surprisingly more difficult than it seems, because you are working with directories of images instead of a single file. This boiler plate will help you download a zipped version of the directory of images. The directory is organized into "train" and "validation" which you can use inside an `ImageGenerator` class to stream batches of images thru your model.

# %% [markdown]
# ### Download & Summarize the Data
#
# This step is completed for you. Just run the cells and review the results.

# %%
import tensorflow as tf
import os

_URL = 'https://github.com/LambdaSchool/DS-Unit-4-Sprint-3-Deep-Learning/blob/main/module2-convolutional-neural-networks/data.zip?raw=true'

path_to_zip = tf.keras.utils.get_file('./data.zip', origin=_URL, extract=True)
PATH = os.path.join(os.path.dirname(path_to_zip), 'data')
# Out:
# Downloading data from https://github.com/LambdaSchool/DS-Unit-4-Sprint-3-Deep-Learning/blob/main/module2-convolutional-neural-networks/data.zip?raw=true
# 42172416/42170838 [==============================] - 1s 0us/step

# %%
train_dir = os.path.join(PATH, 'train')
validation_dir = os.path.join(PATH, 'validation')

# %%
train_mountain_dir = os.path.join(train_dir, 'mountain')  # directory with our training cat pictures
train_forest_dir = os.path.join(train_dir, 'forest')  # directory with our training dog pictures
validation_mountain_dir = os.path.join(validation_dir, 'mountain')  # directory with our validation cat pictures
validation_forest_dir = os.path.join(validation_dir, 'forest')  # directory with our validation dog pictures

# %%
num_mountain_tr = len(os.listdir(train_mountain_dir))
num_forest_tr = len(os.listdir(train_forest_dir))

num_mountain_val = len(os.listdir(validation_mountain_dir))
num_forest_val = len(os.listdir(validation_forest_dir))

total_train = num_mountain_tr + num_forest_tr
total_val = num_mountain_val + num_forest_val

# %%
print('total training mountain images:', num_mountain_tr)
print('total training forest images:', num_forest_tr)

print('total validation mountain images:', num_mountain_val)
print('total validation forest images:', num_forest_val)
print("--")
print("Total training images:", total_train)
print("Total validation images:", total_val)
# Out:
# total training mountain images: 254
# total training forest images: 270
# total validation mountain images: 125
# total validation forest images: 62
# --
# Total training images: 524
# Total validation images: 187

# %% [markdown]
# ### Keras `ImageGenerator` to Process the Data
#
# This step is completed for you, but please review the code. The `ImageGenerator` class reads in batches of data from a directory and pass them to the model one batch at a time. Just like large text files, this method is advantageous, because it stifles the need to load a bunch of images into memory.
#
# Check out the documentation for this class method: [Keras `ImageGenerator` Class](https://keras.io/preprocessing/image/#imagedatagenerator-class). You'll expand it's use in the third assignment objective.

# %%
batch_size = 16
epochs = 50
IMG_HEIGHT = 224
IMG_WIDTH = 224

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_image_generator = ImageDataGenerator(rescale=1./255) # Generator for our training data
validation_image_generator = ImageDataGenerator(rescale=1./255) # Generator for our validation data

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=batch_size,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_HEIGHT, IMG_WIDTH),
                                                           class_mode='binary')
# Out:
# Found 533 images belonging to 2 classes.

# %%
val_data_gen = validation_image_generator.flow_from_directory(batch_size=batch_size,
                                                              directory=validation_dir,
                                                              target_size=(IMG_HEIGHT, IMG_WIDTH),
                                                              class_mode='binary')
# Out:
# Found 195 images belonging to 2 classes.

# %% [markdown]
# ## Instatiate Model

# %%
import numpy as np
# for images - model - layers
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout

# %%
resnet = ResNet50(weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 2s 0us/step

# %%
for layer in resnet.layers:
    layer.trainable = False

x = resnet.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x)
model = Model(resnet.input, predictions)

model.compile(optimizer='Nadam', loss='binary_crossentropy', metrics=['binary_accuracy'])

# %% [markdown]
# ## Fit Model

# %%
history = model.fit(
    train_data_gen,
    steps_per_epoch=total_train // batch_size,
    epochs=epochs,
    validation_data=val_data_gen,
    validation_steps=total_val // batch_size
)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 3s 94ms/step - loss: 0.9052 - binary_accuracy: 0.4830 - val_loss: 0.6137 - val_binary_accuracy: 0.6989
# Epoch 2/50
# 32/32 [==============================] - 2s 67ms/step - loss: 0.7429 - binary_accuracy: 0.5569 - val_loss: 0.5563 - val_binary_accuracy: 0.6648
# Epoch 3/50
# 32/32 [==============================] - 2s 68ms/step - loss: 0.6120 - binary_accuracy: 0.6467 - val_loss: 0.5013 - val_binary_accuracy: 0.7727
# Epoch 4/50
# 32/32 [==============================] - 2s 66ms/step - loss: 0.5566 - binary_accuracy: 0.7166 - val_loss: 0.4924 - val_binary_accuracy: 0.7045
# Epoch 5/50
# 32/32 [==============================] - 2s 67ms/step - loss: 0.5186 - binary_accuracy: 0.7545 - val_loss: 0.4496 - val_binary_accuracy: 0.7045
# Epoch 6/50
# 32/32 [==============================] - 2s 69ms/step - loss: 0.4730 - binary_accuracy: 0.7944 - val_loss: 0.4961 - val_binary_accuracy: 0.8068
# Epoch 7/50
# 32/32 [==============================] - 2s 70ms/step - loss: 0.4972 - binary_accuracy: 0.7585 - val_loss: 0.5557 - val_binary_accuracy: 0.7273
# Epoch 8/50
# 32/32 [==============================] - 2s 67ms/step - loss: 0.4334 - binary_accuracy: 0.8104 - val_loss: 0.5499 - val_binary_accuracy: 0.6875
# Epoch 9/50
# 32/32 [==============================] - 2s 66ms/step - loss: 0.4898 - binary_accuracy: 0.7545 - val_loss: 0.4750 - val_binary_accuracy: 0.8125
# Epoch 10/50
# 32/32 [==============================] - 2s 66ms/step - loss: 0.3919 - binary_accuracy: 0.8423 - val_loss: 0.6457 - val_binary_accuracy: 0.6250
# Epoch 11/50
# 32/32 [==============================] - 2s 66ms/step - loss: 0.3728 - binary_accuracy: 0.8383 - val_loss: 0.3443 - val_binary_accuracy: 0.8466
# Epoch 12/50
# 32/32 [==============================] - 2s 65ms/step - loss: 0.3809 - binary_accuracy: 0.8184 - val_loss: 0.6153 - val_binary_accuracy: 0.6761
# Epoch 13/50
# 32/32 [==============================] - 2s 66ms/step - loss: 0.4531 - binary_accuracy: 0.7844 - val_loss: 0.3715 - val_binary_accuracy: 0.7841
# Epoch 14/50
# 32/32 [==============================] - 2s 67ms/step - loss: 0.3138 - binary_accuracy: 0.9042 - val_loss: 0.3212 - val_binary_accuracy: 0.8636
# Epoch 15/50
# 32/32 [==============================] - 2s 66ms/step - loss: 0.2842 - binary_accuracy: 0.9022 - val_loss: 0.3566 - val_binary_accuracy: 0.8466
# Epoch 16/50
# 32/32 [==============================] - 2s 66ms/step - loss: 0.3072 - binary_accuracy: 0.9002 - val_loss: 0.3092 - val_binary_accuracy: 0.8750
# Epoch 17/50
# 32/32 [==============================] - 2s 66ms/step - loss: 0.3393 - binary_accuracy: 0.8723 - val_loss: 0.3058 - val_binary_accuracy: 0.8750
# Epoch 18/50
# 32/32 [==============================] - 2s 66ms/step - loss: 0.3864 - binary_accuracy: 0.8303 - val_loss: 0.4404 - val_binary_accuracy: 0.8125
# Epoch 19/50
# 32/32 [==============================] - 2s 66ms/step - loss: 0.3011 - binary_accuracy: 0.8723 - val_loss: 0.3022 - val_binary_accuracy: 0.8523
# Epoch 20/50
# 32/32 [==============================] - 2s 67ms/step - loss: 0.2456 - binary_accuracy: 0.9202 - val_loss: 0.3258 - val_binary_accuracy: 0.8239
# Epoch 21/50
# 32/32 [==============================] - 2s 66ms/step - loss: 0.3000 - binary_accuracy: 0.8848 - val_loss: 0.2735 - val_binary_accuracy: 0.9261
# Epoch 22/50
# 32/32 [==============================] - 2s 66ms/step - loss: 0.2980 - binary_accuracy: 0.8882 - val_loss: 0.3168 - val_binary_accuracy: 0.8239
# Epoch 23/50
# 32/32 [==============================] - 2s 66ms/step - loss: 0.2546 - binary_accuracy: 0.9042 - val_loss: 0.3100 - val_binary_accuracy: 0.8182
# Epoch 24/50
# 32/32 [==============================] - 2s 65ms/step - loss: 0.2816 - binary_accuracy: 0.8782 - val_loss: 0.3169 - val_binary_accuracy: 0.8693
# Epoch 25/50
# 32/32 [==============================] - 2s 65ms/step - loss: 0.3265 - binary_accuracy: 0.8663 - val_loss: 0.2593 - val_binary_accuracy: 0.9205
# Epoch 26/50
# 32/32 [==============================] - 2s 66ms/step - loss: 0.2331 - binary_accuracy: 0.9142 - val_loss: 0.5090 - val_binary_accuracy: 0.7955
# Epoch 27/50
# 32/32 [==============================] - 2s 65ms/step - loss: 0.2242 - binary_accuracy: 0.9301 - val_loss: 0.2863 - val_binary_accuracy: 0.8920
# Epoch 28/50
# 32/32 [==============================] - 2s 66ms/step - loss: 0.2712 - binary_accuracy: 0.8882 - val_loss: 0.2948 - val_binary_accuracy: 0.8693
# Epoch 29/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.1923 - binary_accuracy: 0.9441 - val_loss: 0.2376 - val_binary_accuracy: 0.9261
# Epoch 30/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.2086 - binary_accuracy: 0.9182 - val_loss: 0.2140 - val_binary_accuracy: 0.9375
# Epoch 31/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.1923 - binary_accuracy: 0.9301 - val_loss: 0.2642 - val_binary_accuracy: 0.8750
# Epoch 32/50
# 32/32 [==============================] - 2s 63ms/step - loss: 0.1616 - binary_accuracy: 0.9421 - val_loss: 0.3049 - val_binary_accuracy: 0.8693
# Epoch 33/50
# 32/32 [==============================] - 2s 65ms/step - loss: 0.2641 - binary_accuracy: 0.8982 - val_loss: 0.3503 - val_binary_accuracy: 0.8409
# Epoch 34/50
# 32/32 [==============================] - 2s 63ms/step - loss: 0.1874 - binary_accuracy: 0.9341 - val_loss: 0.2126 - val_binary_accuracy: 0.9375
# Epoch 35/50
# 32/32 [==============================] - 2s 65ms/step - loss: 0.2556 - binary_accuracy: 0.8762 - val_loss: 0.2273 - val_binary_accuracy: 0.9205
# Epoch 36/50
# 32/32 [==============================] - 2s 66ms/step - loss: 0.1831 - binary_accuracy: 0.9381 - val_loss: 0.2685 - val_binary_accuracy: 0.8864
# Epoch 37/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.1600 - binary_accuracy: 0.9341 - val_loss: 0.2121 - val_binary_accuracy: 0.9432
# Epoch 38/50
# 32/32 [==============================] - 2s 63ms/step - loss: 0.1451 - binary_accuracy: 0.9541 - val_loss: 0.2694 - val_binary_accuracy: 0.9091
# Epoch 39/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.2802 - binary_accuracy: 0.9142 - val_loss: 0.2176 - val_binary_accuracy: 0.9205
# Epoch 40/50
# 32/32 [==============================] - 2s 63ms/step - loss: 0.2133 - binary_accuracy: 0.8982 - val_loss: 0.2212 - val_binary_accuracy: 0.9261
# Epoch 41/50
# 32/32 [==============================] - 2s 63ms/step - loss: 0.1433 - binary_accuracy: 0.9512 - val_loss: 0.2476 - val_binary_accuracy: 0.9034
# Epoch 42/50
# 32/32 [==============================] - 2s 63ms/step - loss: 0.1419 - binary_accuracy: 0.9601 - val_loss: 0.1951 - val_binary_accuracy: 0.9432
# Epoch 43/50
# 32/32 [==============================] - 2s 62ms/step - loss: 0.1581 - binary_accuracy: 0.9341 - val_loss: 0.3032 - val_binary_accuracy: 0.8409
# Epoch 44/50
# 32/32 [==============================] - 2s 62ms/step - loss: 0.1777 - binary_accuracy: 0.9341 - val_loss: 0.2988 - val_binary_accuracy: 0.8750
# Epoch 45/50
# 32/32 [==============================] - 2s 62ms/step - loss: 0.1507 - binary_accuracy: 0.9321 - val_loss: 0.1752 - val_binary_accuracy: 0.9602
# Epoch 46/50
# 32/32 [==============================] - 2s 62ms/step - loss: 0.1276 - binary_accuracy: 0.9681 - val_loss: 0.2255 - val_binary_accuracy: 0.9318
# Epoch 47/50
# 32/32 [==============================] - 2s 62ms/step - loss: 0.1364 - binary_accuracy: 0.9561 - val_loss: 0.2290 - val_binary_accuracy: 0.9261
# Epoch 48/50
# 32/32 [==============================] - 2s 62ms/step - loss: 0.1197 - binary_accuracy: 0.9541 - val_loss: 0.3651 - val_binary_accuracy: 0.8636
# Epoch 49/50
# 32/32 [==============================] - 2s 62ms/step - loss: 0.1526 - binary_accuracy: 0.9521 - val_loss: 0.3264 - val_binary_accuracy: 0.8636
# Epoch 50/50
# 32/32 [==============================] - 2s 62ms/step - loss: 0.1722 - binary_accuracy: 0.9381 - val_loss: 0.3275 - val_binary_accuracy: 0.8182

# %%
import matplotlib.pyplot as plt
# Vizalizet the relationship between train and val accuracy
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# # Custom CNN Model
#
# In this step, write and train your own convolutional neural network using Keras. You can use any architecture that suits you as long as it has at least one convolutional and one pooling layer at the beginning of the network - you can add more if you want.

# %%
# Define the Model 224, 224, 3
# Setup Architecture
model = Sequential()
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 64)        36928
# _________________________________________________________________
# flatten (Flatten)            (None, 173056)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                11075648
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                650
# =================================================================
# Total params: 11,132,618
# Trainable params: 11,132,618
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile Model
model.compile(optimizer='Nadam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Fit Model
custom = model.fit(
    train_data_gen,
    epochs=50,
    validation_data=val_data_gen
)
# Out:
# Epoch 1/50
# 34/34 [==============================] - 2s 63ms/step - loss: 0.8809 - accuracy: 0.7373 - val_loss: 0.3675 - val_accuracy: 0.9231
# Epoch 2/50
# 34/34 [==============================] - 2s 55ms/step - loss: 0.3505 - accuracy: 0.8837 - val_loss: 0.2878 - val_accuracy: 0.8615
# Epoch 3/50
# 34/34 [==============================] - 2s 55ms/step - loss: 0.3901 - accuracy: 0.8799 - val_loss: 0.1960 - val_accuracy: 0.9231
# Epoch 4/50
# 34/34 [==============================] - 2s 55ms/step - loss: 0.2296 - accuracy: 0.9156 - val_loss: 0.2160 - val_accuracy: 0.9128
# Epoch 5/50
# 34/34 [==============================] - 2s 54ms/step - loss: 0.1641 - accuracy: 0.9343 - val_loss: 0.2256 - val_accuracy: 0.9179
# Epoch 6/50
# 34/34 [==============================] - 2s 53ms/step - loss: 0.3050 - accuracy: 0.8931 - val_loss: 0.2399 - val_accuracy: 0.9026
# Epoch 7/50
# 34/34 [==============================] - 2s 54ms/step - loss: 0.1388 - accuracy: 0.9493 - val_loss: 0.1698 - val_accuracy: 0.9333
# Epoch 8/50
# 34/34 [==============================] - 2s 54ms/step - loss: 0.1831 - accuracy: 0.9381 - val_loss: 0.1920 - val_accuracy: 0.9179
# Epoch 9/50
# 34/34 [==============================] - 2s 54ms/step - loss: 0.1175 - accuracy: 0.9568 - val_loss: 0.1856 - val_accuracy: 0.9179
# Epoch 10/50
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0640 - accuracy: 0.9812 - val_loss: 0.1965 - val_accuracy: 0.9231
# Epoch 11/50
# 34/34 [==============================] - 2s 53ms/step - loss: 0.1018 - accuracy: 0.9662 - val_loss: 0.2146 - val_accuracy: 0.9077
# Epoch 12/50
# 34/34 [==============================] - 2s 56ms/step - loss: 0.0315 - accuracy: 0.9925 - val_loss: 0.3357 - val_accuracy: 0.9282
# Epoch 13/50
# 34/34 [==============================] - 2s 54ms/step - loss: 0.3782 - accuracy: 0.9531 - val_loss: 0.5194 - val_accuracy: 0.7333
# Epoch 14/50
# 34/34 [==============================] - 2s 56ms/step - loss: 0.1486 - accuracy: 0.9437 - val_loss: 0.2086 - val_accuracy: 0.9179
# Epoch 15/50
# 34/34 [==============================] - 2s 55ms/step - loss: 0.0640 - accuracy: 0.9794 - val_loss: 0.4241 - val_accuracy: 0.8872
# Epoch 16/50
# 34/34 [==============================] - 2s 55ms/step - loss: 0.0715 - accuracy: 0.9869 - val_loss: 0.3522 - val_accuracy: 0.9026
# Epoch 17/50
# 34/34 [==============================] - 2s 55ms/step - loss: 0.0672 - accuracy: 0.9812 - val_loss: 0.2305 - val_accuracy: 0.9077
# Epoch 18/50
# 34/34 [==============================] - 2s 56ms/step - loss: 0.0708 - accuracy: 0.9812 - val_loss: 0.1733 - val_accuracy: 0.9333
# Epoch 19/50
# 34/34 [==============================] - 2s 55ms/step - loss: 0.0336 - accuracy: 0.9887 - val_loss: 0.1881 - val_accuracy: 0.9385
# Epoch 20/50
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0101 - accuracy: 0.9981 - val_loss: 0.2984 - val_accuracy: 0.9128
# Epoch 21/50
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0208 - accuracy: 0.9925 - val_loss: 0.3021 - val_accuracy: 0.9179
# Epoch 22/50
# 34/34 [==============================] - 2s 57ms/step - loss: 0.0113 - accuracy: 0.9962 - val_loss: 0.3339 - val_accuracy: 0.9231
# Epoch 23/50
# 34/34 [==============================] - 2s 56ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.4432 - val_accuracy: 0.9282
# Epoch 24/50
# 34/34 [==============================] - 2s 55ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3764 - val_accuracy: 0.9282
# Epoch 25/50
# 34/34 [==============================] - 2s 56ms/step - loss: 0.0041 - accuracy: 0.9981 - val_loss: 0.3120 - val_accuracy: 0.9385
# Epoch 26/50
# 34/34 [==============================] - 2s 55ms/step - loss: 0.0130 - accuracy: 0.9962 - val_loss: 0.2896 - val_accuracy: 0.9333
# Epoch 27/50
# 34/34 [==============================] - 2s 56ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4106 - val_accuracy: 0.9282
# Epoch 28/50
# 34/34 [==============================] - 2s 53ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.6123 - val_accuracy: 0.9282
# Epoch 29/50
# 34/34 [==============================] - 2s 53ms/step - loss: 0.0098 - accuracy: 0.9981 - val_loss: 0.2892 - val_accuracy: 0.9282
# Epoch 30/50
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.3770 - val_accuracy: 0.9385
# Epoch 31/50
# 34/34 [==============================] - 2s 54ms/step - loss: 9.2463e-04 - accuracy: 1.0000 - val_loss: 0.3815 - val_accuracy: 0.9333
# Epoch 32/50
# 34/34 [==============================] - 2s 54ms/step - loss: 9.1452e-04 - accuracy: 1.0000 - val_loss: 0.4828 - val_accuracy: 0.9333
# Epoch 33/50
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.9213 - val_accuracy: 0.8923
# Epoch 34/50
# 34/34 [==============================] - 2s 53ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.3968 - val_accuracy: 0.9333
# Epoch 35/50
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5722 - val_accuracy: 0.9077
# Epoch 36/50
# 34/34 [==============================] - 2s 55ms/step - loss: 7.4297e-04 - accuracy: 1.0000 - val_loss: 0.6313 - val_accuracy: 0.9026
# Epoch 37/50
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5451 - val_accuracy: 0.9333
# Epoch 38/50
# 34/34 [==============================] - 2s 53ms/step - loss: 3.6891e-04 - accuracy: 1.0000 - val_loss: 0.5471 - val_accuracy: 0.9333
# Epoch 39/50
# 34/34 [==============================] - 2s 53ms/step - loss: 6.7524e-04 - accuracy: 1.0000 - val_loss: 0.4743 - val_accuracy: 0.9385
# Epoch 40/50
# 34/34 [==============================] - 2s 54ms/step - loss: 2.5285e-04 - accuracy: 1.0000 - val_loss: 0.5458 - val_accuracy: 0.9282
# Epoch 41/50
# 34/34 [==============================] - 2s 53ms/step - loss: 7.1043e-04 - accuracy: 1.0000 - val_loss: 0.6720 - val_accuracy: 0.9282
# Epoch 42/50
# 34/34 [==============================] - 2s 53ms/step - loss: 2.8923e-04 - accuracy: 1.0000 - val_loss: 0.7422 - val_accuracy: 0.9179
# Epoch 43/50
# 34/34 [==============================] - 2s 53ms/step - loss: 0.4344 - accuracy: 0.8893 - val_loss: 0.5372 - val_accuracy: 0.7795
# Epoch 44/50
# 34/34 [==============================] - 2s 53ms/step - loss: 0.1665 - accuracy: 0.9325 - val_loss: 0.1862 - val_accuracy: 0.9231
# Epoch 45/50
# 34/34 [==============================] - 2s 53ms/step - loss: 0.1203 - accuracy: 0.9625 - val_loss: 0.3154 - val_accuracy: 0.8718
# Epoch 46/50
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0720 - accuracy: 0.9700 - val_loss: 0.2290 - val_accuracy: 0.9128
# Epoch 47/50
# 34/34 [==============================] - 2s 55ms/step - loss: 0.0303 - accuracy: 0.9906 - val_loss: 0.2313 - val_accuracy: 0.9385
# Epoch 48/50
# 34/34 [==============================] - 2s 53ms/step - loss: 0.0726 - accuracy: 0.9794 - val_loss: 0.1846 - val_accuracy: 0.9385
# Epoch 49/50
# 34/34 [==============================] - 2s 53ms/step - loss: 0.0307 - accuracy: 0.9869 - val_loss: 0.5103 - val_accuracy: 0.8872
# Epoch 50/50
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0350 - accuracy: 0.9906 - val_loss: 0.2117 - val_accuracy: 0.9436

# %%
# Evaluate Model 

model.evaluate(val_data_gen)
# Out:
# 13/13 [==============================] - 0s 33ms/step - loss: 0.2117 - accuracy: 0.9436
# [0.21174101531505585, 0.9435897469520569]

# %%
# Vizalizet the relationship between train and val accuracy
accc = custom.history['accuracy']
val_accc = custom.history['val_accuracy']

losss = custom.history['loss']
val_losss = custom.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(accc, label='Training Accuracy')
plt.plot(val_accc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(losss, label='Training Loss')
plt.plot(val_losss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# # Custom CNN Model with Image Manipulations
#
# To simulate an increase in a sample of image, you can apply image manipulation techniques: cropping, rotation, stretching, etc. Luckily Keras has some handy functions for us to apply these techniques to our mountain and forest example. Simply, you should be able to modify our image generator for the problem. Check out these resources to help you get started:
#
# 1. [Keras `ImageGenerator` Class](https://keras.io/preprocessing/image/#imagedatagenerator-class)
# 2. [Building a powerful image classifier with very little data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html)

# %%
train_image_generator = ImageDataGenerator(rescale=1./255, rotation_range=90, width_shift_range=.5, height_shift_range=.5)
validation_image_generator = ImageDataGenerator(rescale=1./255, rotation_range=90, width_shift_range=.5, height_shift_range=.5)

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=batch_size,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_HEIGHT, IMG_WIDTH),
                                                           class_mode='binary')
# Out:
# Found 533 images belonging to 2 classes.

# %%
val_data_gen = validation_image_generator.flow_from_directory(batch_size=batch_size,
                                                              directory=validation_dir,
                                                              target_size=(IMG_HEIGHT, IMG_WIDTH),
                                                              class_mode='binary')
# Out:
# Found 195 images belonging to 2 classes.

# %%
# Define the Model 224, 224, 3
# Setup Architecture
model = Sequential()
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 111, 111, 32)      0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 52, 52, 64)        36928
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 173056)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                11075648
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                650
# =================================================================
# Total params: 11,132,618
# Trainable params: 11,132,618
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile Model
model.compile(optimizer='Nadam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
imagemal = model.fit(
    train_data_gen,
    epochs=30,batch_size=2,
    validation_data=val_data_gen
)
# Out:
# Epoch 1/30
# 34/34 [==============================] - 9s 257ms/step - loss: 1.3353 - accuracy: 0.5966 - val_loss: 0.5598 - val_accuracy: 0.8103
# Epoch 2/30
# 34/34 [==============================] - 9s 257ms/step - loss: 0.5183 - accuracy: 0.7861 - val_loss: 0.5108 - val_accuracy: 0.7949
# Epoch 3/30
# 34/34 [==============================] - 9s 254ms/step - loss: 0.4195 - accuracy: 0.8386 - val_loss: 0.4104 - val_accuracy: 0.8308
# Epoch 4/30
# 34/34 [==============================] - 8s 244ms/step - loss: 0.4328 - accuracy: 0.8180 - val_loss: 0.4475 - val_accuracy: 0.8051
# Epoch 5/30
# 34/34 [==============================] - 8s 244ms/step - loss: 0.3542 - accuracy: 0.8499 - val_loss: 0.3836 - val_accuracy: 0.8513
# Epoch 6/30
# 34/34 [==============================] - 8s 246ms/step - loss: 0.4638 - accuracy: 0.8537 - val_loss: 0.3660 - val_accuracy: 0.8564
# Epoch 7/30
# 34/34 [==============================] - 8s 244ms/step - loss: 0.3629 - accuracy: 0.8555 - val_loss: 0.5519 - val_accuracy: 0.7179
# Epoch 8/30
# 34/34 [==============================] - 8s 245ms/step - loss: 0.3095 - accuracy: 0.8780 - val_loss: 0.4099 - val_accuracy: 0.7949
# Epoch 9/30
# 34/34 [==============================] - 8s 247ms/step - loss: 0.3284 - accuracy: 0.8612 - val_loss: 0.3933 - val_accuracy: 0.8154
# Epoch 10/30
# 34/34 [==============================] - 8s 245ms/step - loss: 0.2970 - accuracy: 0.8912 - val_loss: 0.3175 - val_accuracy: 0.8564
# Epoch 11/30
# 34/34 [==============================] - 8s 247ms/step - loss: 0.3044 - accuracy: 0.8912 - val_loss: 0.3562 - val_accuracy: 0.8359
# Epoch 12/30
# 34/34 [==============================] - 8s 246ms/step - loss: 0.3108 - accuracy: 0.8705 - val_loss: 0.4776 - val_accuracy: 0.8103
# Epoch 13/30
# 34/34 [==============================] - 8s 245ms/step - loss: 0.3354 - accuracy: 0.8780 - val_loss: 0.2952 - val_accuracy: 0.8564
# Epoch 14/30
# 34/34 [==============================] - 8s 244ms/step - loss: 0.2766 - accuracy: 0.8912 - val_loss: 0.2849 - val_accuracy: 0.8769
# Epoch 15/30
# 34/34 [==============================] - 8s 244ms/step - loss: 0.3257 - accuracy: 0.8687 - val_loss: 0.3200 - val_accuracy: 0.8462
# Epoch 16/30
# 34/34 [==============================] - 8s 246ms/step - loss: 0.2796 - accuracy: 0.8949 - val_loss: 0.2647 - val_accuracy: 0.9026
# Epoch 17/30
# 34/34 [==============================] - 8s 244ms/step - loss: 0.3332 - accuracy: 0.8518 - val_loss: 0.3611 - val_accuracy: 0.8000
# Epoch 18/30
# 34/34 [==============================] - 8s 245ms/step - loss: 0.2622 - accuracy: 0.8912 - val_loss: 0.2838 - val_accuracy: 0.8718
# Epoch 19/30
# 34/34 [==============================] - 8s 246ms/step - loss: 0.2984 - accuracy: 0.9043 - val_loss: 0.2640 - val_accuracy: 0.8872
# Epoch 20/30
# 34/34 [==============================] - 8s 245ms/step - loss: 0.2122 - accuracy: 0.9250 - val_loss: 0.3041 - val_accuracy: 0.8718
# Epoch 21/30
# 34/34 [==============================] - 8s 247ms/step - loss: 0.2807 - accuracy: 0.8856 - val_loss: 0.2561 - val_accuracy: 0.8667
# Epoch 22/30
# 34/34 [==============================] - 8s 245ms/step - loss: 0.2991 - accuracy: 0.8780 - val_loss: 0.3227 - val_accuracy: 0.8205
# Epoch 23/30
# 34/34 [==============================] - 8s 249ms/step - loss: 0.3375 - accuracy: 0.8949 - val_loss: 0.3683 - val_accuracy: 0.8154
# Epoch 24/30
# 34/34 [==============================] - 8s 245ms/step - loss: 0.2830 - accuracy: 0.8931 - val_loss: 0.2971 - val_accuracy: 0.8821
# Epoch 25/30
# 34/34 [==============================] - 8s 246ms/step - loss: 0.2643 - accuracy: 0.8968 - val_loss: 0.2805 - val_accuracy: 0.8718
# Epoch 26/30
# 34/34 [==============================] - 8s 242ms/step - loss: 0.2506 - accuracy: 0.9062 - val_loss: 0.3149 - val_accuracy: 0.8564
# Epoch 27/30
# 34/34 [==============================] - 8s 243ms/step - loss: 0.2493 - accuracy: 0.8949 - val_loss: 0.3038 - val_accuracy: 0.8667
# Epoch 28/30
# 34/34 [==============================] - 8s 244ms/step - loss: 0.2604 - accuracy: 0.8912 - val_loss: 0.4014 - val_accuracy: 0.8205
# Epoch 29/30
# 34/34 [==============================] - 8s 245ms/step - loss: 0.3113 - accuracy: 0.8837 - val_loss: 0.2968 - val_accuracy: 0.8615
# Epoch 30/30
# 34/34 [==============================] - 8s 250ms/step - loss: 0.2748 - accuracy: 0.8968 - val_loss: 0.2567 - val_accuracy: 0.8872

# %%
# Evaluate Model

model.evaluate(val_data_gen)
# Out:
# 13/13 [==============================] - 2s 158ms/step - loss: 0.2755 - accuracy: 0.8821
# [0.27546626329421997, 0.8820512890815735]

# %%
# Evaluate Model

model.evaluate(train_data_gen)
# Out:
# 34/34 [==============================] - 6s 178ms/step - loss: 0.2454 - accuracy: 0.9099
# [0.2453758716583252, 0.909943699836731]

# %%
# Vizalizet the relationship between train and val accuracy
acc = imagemal.history['accuracy']
val_acc = imagemal.history['val_accuracy']

loss = imagemal.history['loss']
val_loss = imagemal.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
# Define the Model 224, 224, 3
# Setup Architecture
model = Sequential()
model.add(Conv2D(64, (3,3), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(128, (3,3), activation='relu'))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 222, 222, 64)      1792
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 111, 111, 64)      0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 111, 111, 64)      0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 109, 109, 128)     73856
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 54, 54, 128)       0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 52, 52, 128)       147584
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 346112)            0
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               44302464
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                8256
# =================================================================
# Total params: 44,533,952
# Trainable params: 44,533,952
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile Model
model.compile(optimizer='Adamax',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
morenurons = model.fit(
    train_data_gen,
    epochs=30,batch_size=2,
    validation_data=val_data_gen
)
# Out:
# Epoch 1/30
# 34/34 [==============================] - 9s 264ms/step - loss: 0.4081 - accuracy: 0.8424 - val_loss: 0.3190 - val_accuracy: 0.8718
# Epoch 2/30
# 34/34 [==============================] - 9s 255ms/step - loss: 0.2708 - accuracy: 0.8931 - val_loss: 0.3388 - val_accuracy: 0.8513
# Epoch 3/30
# 34/34 [==============================] - 9s 257ms/step - loss: 0.2906 - accuracy: 0.9081 - val_loss: 0.3358 - val_accuracy: 0.8564
# Epoch 4/30
# 34/34 [==============================] - 9s 252ms/step - loss: 0.2812 - accuracy: 0.9081 - val_loss: 0.2968 - val_accuracy: 0.8769
# Epoch 5/30
# 34/34 [==============================] - 9s 259ms/step - loss: 0.2830 - accuracy: 0.8968 - val_loss: 0.3191 - val_accuracy: 0.8923
# Epoch 6/30
# 34/34 [==============================] - 9s 255ms/step - loss: 0.2575 - accuracy: 0.9006 - val_loss: 0.4528 - val_accuracy: 0.7949
# Epoch 7/30
# 34/34 [==============================] - 9s 257ms/step - loss: 0.2487 - accuracy: 0.8987 - val_loss: 0.3333 - val_accuracy: 0.8667
# Epoch 8/30
# 34/34 [==============================] - 9s 252ms/step - loss: 0.2462 - accuracy: 0.9043 - val_loss: 0.2721 - val_accuracy: 0.8718
# Epoch 9/30
# 34/34 [==============================] - 9s 265ms/step - loss: 0.2532 - accuracy: 0.9062 - val_loss: 0.3232 - val_accuracy: 0.8513
# Epoch 10/30
# 34/34 [==============================] - 9s 257ms/step - loss: 0.2550 - accuracy: 0.8968 - val_loss: 0.2852 - val_accuracy: 0.8667
# Epoch 11/30
# 34/34 [==============================] - 9s 253ms/step - loss: 0.2716 - accuracy: 0.8762 - val_loss: 0.2968 - val_accuracy: 0.8667
# Epoch 12/30
# 34/34 [==============================] - 9s 252ms/step - loss: 0.2319 - accuracy: 0.8949 - val_loss: 0.2898 - val_accuracy: 0.8769
# Epoch 13/30
# 34/34 [==============================] - 9s 255ms/step - loss: 0.2174 - accuracy: 0.9174 - val_loss: 0.3360 - val_accuracy: 0.8513
# Epoch 14/30
# 34/34 [==============================] - 9s 261ms/step - loss: 0.2384 - accuracy: 0.9081 - val_loss: 0.2333 - val_accuracy: 0.8872
# Epoch 15/30
# 34/34 [==============================] - 9s 255ms/step - loss: 0.2255 - accuracy: 0.9081 - val_loss: 0.2774 - val_accuracy: 0.8821
# Epoch 16/30
# 34/34 [==============================] - 9s 258ms/step - loss: 0.2289 - accuracy: 0.9174 - val_loss: 0.2431 - val_accuracy: 0.8974
# Epoch 17/30
# 34/34 [==============================] - 9s 252ms/step - loss: 0.2321 - accuracy: 0.9081 - val_loss: 0.2518 - val_accuracy: 0.8872
# Epoch 18/30
# 34/34 [==============================] - 9s 253ms/step - loss: 0.1844 - accuracy: 0.9193 - val_loss: 0.2736 - val_accuracy: 0.9026
# Epoch 19/30
# 34/34 [==============================] - 9s 262ms/step - loss: 0.2367 - accuracy: 0.9156 - val_loss: 0.2018 - val_accuracy: 0.9179
# Epoch 20/30
# 34/34 [==============================] - 9s 252ms/step - loss: 0.1766 - accuracy: 0.9156 - val_loss: 0.2303 - val_accuracy: 0.9231
# Epoch 21/30
# 34/34 [==============================] - 9s 251ms/step - loss: 0.2679 - accuracy: 0.9137 - val_loss: 0.2990 - val_accuracy: 0.8564
# Epoch 22/30
# 34/34 [==============================] - 9s 253ms/step - loss: 0.2118 - accuracy: 0.9287 - val_loss: 0.2558 - val_accuracy: 0.8923
# Epoch 23/30
# 34/34 [==============================] - 9s 259ms/step - loss: 0.2155 - accuracy: 0.9250 - val_loss: 0.2661 - val_accuracy: 0.8974
# Epoch 24/30
# 34/34 [==============================] - 9s 252ms/step - loss: 0.2334 - accuracy: 0.9062 - val_loss: 0.2926 - val_accuracy: 0.8615
# Epoch 25/30
# 34/34 [==============================] - 8s 250ms/step - loss: 0.1846 - accuracy: 0.9325 - val_loss: 0.2459 - val_accuracy: 0.8821
# Epoch 26/30
# 34/34 [==============================] - 9s 251ms/step - loss: 0.2427 - accuracy: 0.9043 - val_loss: 0.2918 - val_accuracy: 0.8513
# Epoch 27/30
# 34/34 [==============================] - 9s 255ms/step - loss: 0.1964 - accuracy: 0.9212 - val_loss: 0.2831 - val_accuracy: 0.8974
# Epoch 28/30
# 34/34 [==============================] - 9s 253ms/step - loss: 0.2250 - accuracy: 0.9062 - val_loss: 0.2400 - val_accuracy: 0.8821
# Epoch 29/30
# 34/34 [==============================] - 8s 249ms/step - loss: 0.1951 - accuracy: 0.9268 - val_loss: 0.3164 - val_accuracy: 0.8615
# Epoch 30/30
# 34/34 [==============================] - 9s 250ms/step - loss: 0.1557 - accuracy: 0.9287 - val_loss: 0.3314 - val_accuracy: 0.8615

# %%
# Evaluate Model

model.evaluate(val_data_gen)
# Out:
# 13/13 [==============================] - 2s 158ms/step - loss: 0.3270 - accuracy: 0.8462
# [0.3269766867160797, 0.8461538553237915]

# %%
# Vizalizet the relationship between train and val accuracy
acc = morenurons.history['accuracy']
val_acc = morenurons.history['val_accuracy']

loss = morenurons.history['loss']
val_loss = morenurons.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
import numpy as np

from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions

def process_img_path(img_path):
  return image.load_img(img_path, target_size=(224, 224))

def img_contains_banana(img):
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
  x = preprocess_input(x)
  model = ResNet50(weights='imagenet')
  features = model.predict(x)
  results = decode_predictions(features, top=3)[0]
  print(results)
  for entry in results:
    if entry[1] == 'banana':
      return entry[2]
  return 0.0

# %%
import requests

image_urls = [
              "https://github.com/LambdaSchool/ML-YouOnlyLookOnce/raw/master/sample_data/positive_examples/example0.jpeg",
              "https://github.com/LambdaSchool/ML-YouOnlyLookOnce/raw/master/sample_data/positive_examples/example1.jpeg",
              "https://github.com/LambdaSchool/ML-YouOnlyLookOnce/raw/master/sample_data/positive_examples/example2.jpeg"]

for _id,img in enumerate(image_urls): 
    r = requests.get(img)
    with open(f'example{_id}.jpg', 'wb') as f:
        f.write(r.content)

# %%
from IPython.display import Image
Image(filename='./example0.jpg', width=600)

# %%
img_contains_banana(process_img_path('example0.jpg'))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f20467d4730> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [('n04037443', 'racer', 0.92562824), ('n04285008', 'sports_car', 0.07028788), ('n04461696', 'tow_truck', 0.0021220406)]
# 0.0

# %%
Image(filename='example1.jpg', width=600)

# %%
img_contains_banana(process_img_path('example1.jpg'))
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f20482aeae8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [('n04275548', 'spider_web', 0.27565327), ('n02909870', 'bucket', 0.08577717), ('n03532672', 'hook', 0.079121895)]
# 0.0

# %%
Image(filename='example1.jpg', width=600)

# %%
img_contains_banana(process_img_path('example1.jpg'))
# Out:
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f20448f4f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [('n04275548', 'spider_web', 0.27565327), ('n02909870', 'bucket', 0.08577717), ('n03532672', 'hook', 0.079121895)]
# 0.0

# %%
Image(filename='example2.jpg', width=600)

# %%
img_contains_banana(process_img_path('example2.jpg'))
# Out:
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f20430de730> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [('n07753592', 'banana', 0.9903454), ('n07747607', 'orange', 0.0051709753), ('n07749582', 'lemon', 0.0031872343)]
# 0.9903454

# %% [markdown]
# # Resources and Stretch Goals
#
# Stretch goals
# - Enhance your code to use classes/functions and accept terms to search and classes to look for in recognizing the downloaded images (e.g. download images of parties, recognize all that contain balloons)
# - Check out [other available pretrained networks](https://tfhub.dev), try some and compare
# - Image recognition/classification is somewhat solved, but *relationships* between entities and describing an image is not - check out some of the extended resources (e.g. [Visual Genome](https://visualgenome.org/)) on the topic
# - Transfer learning - using images you source yourself, [retrain a classifier](https://www.tensorflow.org/hub/tutorials/image_retraining) with a new category
# - (Not CNN related) Use [piexif](https://pypi.org/project/piexif/) to check out the metadata of images passed in to your system - see if they're from a national park! (Note - many images lack GPS metadata, so this won't work in most cases, but still cool)
#
# Resources
# - [Deep Residual Learning for Image Recognition](https://arxiv.org/abs/1512.03385) - influential paper (introduced ResNet)
# - [YOLO: Real-Time Object Detection](https://pjreddie.com/darknet/yolo/) - an influential convolution based object detection system, focused on inference speed (for applications to e.g. self driving vehicles)
# - [R-CNN, Fast R-CNN, Faster R-CNN, YOLO](https://towardsdatascience.com/r-cnn-fast-r-cnn-faster-r-cnn-yolo-object-detection-algorithms-36d53571365e) - comparison of object detection systems
# - [Common Objects in Context](http://cocodataset.org/) - a large-scale object detection, segmentation, and captioning dataset
# - [Visual Genome](https://visualgenome.org/) - a dataset, a knowledge base, an ongoing effort to connect structured image concepts to language
